# %%
#load dateset 
import pandas as pd
import numpy as np

df_socialm=pd.read_csv("OnlineNewsPopularity.csv")
df_socialm
# Out:
#                                                      url  timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
# ...                                                  ...        ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...        8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...        8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...        8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/        8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...        8.0
#
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0                12.0             219.0         0.663594               1.0
# 1                 9.0             255.0         0.604743               1.0
# 2                 9.0             211.0         0.575130               1.0
# 3                 9.0             531.0         0.503788               1.0
# 4                13.0            1072.0         0.415646               1.0
# ...               ...               ...              ...               ...
# 39639            11.0             346.0         0.529052               1.0
# 39640            12.0             328.0         0.696296               1.0
# 39641            10.0             442.0         0.516355               1.0
# 39642             6.0             682.0         0.539493               1.0
# 39643            10.0             157.0         0.701987               1.0
#
#        n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                      0.815385        4.0             2.0       1.0  ...
# 1                      0.791946        3.0             1.0       1.0  ...
# 2                      0.663866        3.0             1.0       1.0  ...
# 3                      0.665635        9.0             0.0       1.0  ...
# 4                      0.540890       19.0            19.0      20.0  ...
# ...                         ...        ...             ...       ...  ...
# 39639                  0.684783        9.0             7.0       1.0  ...
# 39640                  0.885057        9.0             7.0       3.0  ...
# 39641                  0.644128       24.0             1.0      12.0  ...
# 39642                  0.692661       10.0             1.0       1.0  ...
# 39643                  0.846154        1.0             1.0       0.0  ...
#
#        min_positive_polarity  max_positive_polarity  avg_negative_polarity  \
# 0                   0.100000                   0.70              -0.350000
# 1                   0.033333                   0.70              -0.118750
# 2                   0.100000                   1.00              -0.466667
# 3                   0.136364                   0.80              -0.369697
# 4                   0.033333                   1.00              -0.220192
# ...                      ...                    ...                    ...
# 39639               0.100000                   0.75              -0.260000
# 39640               0.136364                   0.70              -0.211111
# 39641               0.136364                   0.50              -0.356439
# 39642               0.062500                   0.50              -0.205246
# 39643               0.100000                   0.50              -0.200000
#
#        min_negative_polarity  max_negative_polarity  title_subjectivity  \
# 0                     -0.600              -0.200000            0.500000
# 1                     -0.125              -0.100000            0.000000
# 2                     -0.800              -0.133333            0.000000
# 3                     -0.600              -0.166667            0.000000
# 4                     -0.500              -0.050000            0.454545
# ...                      ...                    ...                 ...
# 39639                 -0.500              -0.125000            0.100000
# 39640                 -0.400              -0.100000            0.300000
# 39641                 -0.800              -0.166667            0.454545
# 39642                 -0.500              -0.012500            0.000000
# 39643                 -0.200              -0.200000            0.333333
#
#        title_sentiment_polarity  abs_title_subjectivity  \
# 0                     -0.187500                0.000000
# 1                      0.000000                0.500000
# 2                      0.000000                0.500000
# 3                      0.000000                0.500000
# 4                      0.136364                0.045455
# ...                         ...                     ...
# 39639                  0.000000                0.400000
# 39640                  1.000000                0.200000
# 39641                  0.136364                0.045455
# 39642                  0.000000                0.500000
# 39643                  0.250000                0.166667
#
#        abs_title_sentiment_polarity  shares
# 0                          0.187500     593
# 1                          0.000000     711
# 2                          0.000000    1500
# 3                          0.000000    1200
# 4                          0.136364     505
# ...                             ...     ...
# 39639                      0.000000    1800
# 39640                      1.000000    1900
# 39641                      0.136364    1900
# 39642                      0.000000    1100
# 39643                      0.250000    1300
#
# [39644 rows x 61 columns]

# %%
#dataset content
df_socialm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
# url                               39644 non-null object
# timedelta                         39644 non-null float64
# n_tokens_title                    39644 non-null float64
# n_tokens_content                  39644 non-null float64
# n_unique_tokens                   39644 non-null float64
# n_non_stop_words                  39644 non-null float64
# n_non_stop_unique_tokens          39644 non-null float64
# num_hrefs                         39644 non-null float64
# num_self_hrefs                    39644 non-null float64
# num_imgs                          39644 non-null float64
# num_videos                        39644 non-null float64
# average_token_length              39644 non-null float64
# num_keywords                      39644 non-null float64
# data_channel_is_lifestyle         39644 non-null float64
#  data_channel_is_entertainment    39644 non-null float64
# data_channel_is_bus               39644 non-null float64
# data_channel_is_socmed            39644 non-null float64
# data_channel_is_tech              39644 non-null float64
# data_channel_is_world             39644 non-null float64
# kw_min_min                        39644 non-null float64
# kw_max_min                        39644 non-null float64
# kw_avg_min                        39644 non-null float64
# kw_min_max                        39644 non-null float64
# kw_max_max                        39644 non-null float64
# kw_avg_max                        39644 non-null float64
# kw_min_avg                        39644 non-null float64
# kw_max_avg                        39644 non-null float64
# kw_avg_avg                        39644 non-null float64
# self_reference_min_shares         39644 non-null float64
# self_reference_max_shares         39644 non-null float64
# self_reference_avg_sharess        39644 non-null float64
# weekday_is_monday                 39644 non-null float64
# weekday_is_tuesday                39644 non-null float64
# weekday_is_wednesday              39644 non-null float64
# weekday_is_thursday               39644 non-null float64
# weekday_is_friday                 39644 non-null float64
# weekday_is_saturday               39644 non-null float64
# weekday_is_sunday                 39644 non-null float64
# is_weekend                        39644 non-null float64
# LDA_00                            39644 non-null float64
# LDA_01                            39644 non-null float64
# LDA_02                            39644 non-null float64
# LDA_03                            39644 non-null float64
# LDA_04                            39644 non-null float64
# global_subjectivity               39644 non-null float64
# global_sentiment_polarity         39644 non-null float64
# global_rate_positive_words        39644 non-null float64
# global_rate_negative_words        39644 non-null float64
# rate_positive_words               39644 non-null float64
# rate_negative_words               39644 non-null float64
# avg_positive_polarity             39644 non-null float64
# min_positive_polarity             39644 non-null float64
# max_positive_polarity             39644 non-null float64
# avg_negative_polarity             39644 non-null float64
# min_negative_polarity             39644 non-null float64
# max_negative_polarity             39644 non-null float64
# title_subjectivity                39644 non-null float64
# title_sentiment_polarity          39644 non-null float64
# abs_title_subjectivity            39644 non-null float64
# abs_title_sentiment_polarity      39644 non-null float64
# shares                            39644 non-null int64
# dtypes: float64(59), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
#convert to 0/1
df_socialm['target'] = df_socialm['shares'].apply(lambda x: 1 if x >3272 else 0)

# %%
df_socialm.target.value_counts()
# Out:
# 0    31306
# 1     8338
# Name: target, dtype: int64

# %%
df_socialm.drop('shares',axis=1,inplace=True)

# %%
#descriptive stats
df_socialm.target.value_counts()/len(df_socialm)
# Out:
# 0    0.789678
# 1    0.210322
# Name: target, dtype: float64

# %%
df_socialm.describe()
# Out:
#           timedelta  n_tokens_title  n_tokens_content  n_unique_tokens  \
# count  39644.000000    39644.000000      39644.000000     39644.000000
# mean     354.530471       10.398749        546.514731         0.548216
# std      214.163767        2.114037        471.107508         3.520708
# min        8.000000        2.000000          0.000000         0.000000
# 25%      164.000000        9.000000        246.000000         0.470870
# 50%      339.000000       10.000000        409.000000         0.539226
# 75%      542.000000       12.000000        716.000000         0.608696
# max      731.000000       23.000000       8474.000000       701.000000
#
#        n_non_stop_words  n_non_stop_unique_tokens     num_hrefs  \
# count      39644.000000              39644.000000  39644.000000
# mean           0.996469                  0.689175     10.883690
# std            5.231231                  3.264816     11.332017
# min            0.000000                  0.000000      0.000000
# 25%            1.000000                  0.625739      4.000000
# 50%            1.000000                  0.690476      8.000000
# 75%            1.000000                  0.754630     14.000000
# max         1042.000000                650.000000    304.000000
#
#        num_self_hrefs      num_imgs    num_videos  ...  min_positive_polarity  \
# count    39644.000000  39644.000000  39644.000000  ...           39644.000000
# mean         3.293638      4.544143      1.249874  ...               0.095446
# std          3.855141      8.309434      4.107855  ...               0.071315
# min          0.000000      0.000000      0.000000  ...               0.000000
# 25%          1.000000      1.000000      0.000000  ...               0.050000
# 50%          3.000000      1.000000      0.000000  ...               0.100000
# 75%          4.000000      4.000000      1.000000  ...               0.100000
# max        116.000000    128.000000     91.000000  ...               1.000000
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# count           39644.000000           39644.000000           39644.000000
# mean                0.756728              -0.259524              -0.521944
# std                 0.247786               0.127726               0.290290
# min                 0.000000              -1.000000              -1.000000
# 25%                 0.600000              -0.328383              -0.700000
# 50%                 0.800000              -0.253333              -0.500000
# 75%                 1.000000              -0.186905              -0.300000
# max                 1.000000               0.000000               0.000000
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# count           39644.000000        39644.000000              39644.000000
# mean               -0.107500            0.282353                  0.071425
# std                 0.095373            0.324247                  0.265450
# min                -1.000000            0.000000                 -1.000000
# 25%                -0.125000            0.000000                  0.000000
# 50%                -0.100000            0.150000                  0.000000
# 75%                -0.050000            0.500000                  0.150000
# max                 0.000000            1.000000                  1.000000
#
#        abs_title_subjectivity  abs_title_sentiment_polarity        target
# count            39644.000000                  39644.000000  39644.000000
# mean                 0.341843                      0.156064      0.210322
# std                  0.188791                      0.226294      0.407542
# min                  0.000000                      0.000000      0.000000
# 25%                  0.166667                      0.000000      0.000000
# 50%                  0.500000                      0.000000      0.000000
# 75%                  0.500000                      0.250000      0.000000
# max                  0.500000                      1.000000      1.000000
#
# [8 rows x 60 columns]

# %%
df_socialm.dtypes
# Out:
# url                              object
# timedelta                       float64
# n_tokens_title                  float64
# n_tokens_content                float64
# n_unique_tokens                 float64
#                                  ...
# title_subjectivity              float64
# title_sentiment_polarity        float64
# abs_title_subjectivity          float64
# abs_title_sentiment_polarity    float64
# target                            int64
# Length: 61, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.subplots(figsize=(30,30))
corr = df_socialm.corr()
sns.heatmap(corr,
           xticklabels=corr.columns,
           yticklabels=corr.columns, linewidth=.5)
plt.show()

# %%
#Variable Selection using Python - Vote based approach
# Convert categorical values to numeric using label encoder
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)

# Encoding the categorical variable
fit = df_socialm.select_dtypes(include=['object']).fillna('NA').apply(lambda x: d[x.name].fit_transform(x))

#Convert the categorical columns based on encoding
for i in list(d.keys()):
    df_socialm[i] = d[i].transform(df_socialm[i].fillna('NA'))

# %%
features=df_socialm[df_socialm.columns.difference(["target"])]
labels =df_socialm["target"]

# %%
features=features.fillna(0)

# %%
# import packages
import pandas as pd
import numpy as np
import pandas.core.algorithms as algos
from pandas import Series
import scipy.stats.stats as stats
import re
import traceback
import string

max_bin = 20
force_bin = 3

# define a binning function
def mono_bin(Y, X, n = max_bin):
    
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]
    r = 0
    while np.abs(r) < 1:
        try:
            d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.qcut(notmiss.X, n)})
            d2 = d1.groupby('Bucket', as_index=True)
            r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
            n = n - 1 
        except Exception as e:
            n = n - 1

    if len(d2) == 1:
        n = force_bin         
        bins = algos.quantile(notmiss.X, np.linspace(0, 1, n))
        if len(np.unique(bins)) == 2:
            bins = np.insert(bins, 0, 1)
            bins[1] = bins[1]-(bins[1]/2)
        d1 = pd.DataFrame({"X": notmiss.X, "Y": notmiss.Y, "Bucket": pd.cut(notmiss.X, np.unique(bins),include_lowest=True)}) 
        d2 = d1.groupby('Bucket', as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["MIN_VALUE"] = d2.min().X
    d3["MAX_VALUE"] = d2.max().X
    d3["COUNT"] = d2.count().Y
    d3["EVENT"] = d2.sum().Y
    d3["NONEVENT"] = d2.count().Y - d2.sum().Y
    d3=d3.reset_index(drop=True)
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]       
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    
    return(d3)

def char_bin(Y, X):
        
    df1 = pd.DataFrame({"X": X, "Y": Y})
    justmiss = df1[['X','Y']][df1.X.isnull()]
    notmiss = df1[['X','Y']][df1.X.notnull()]    
    df2 = notmiss.groupby('X',as_index=True)
    
    d3 = pd.DataFrame({},index=[])
    d3["COUNT"] = df2.count().Y
    d3["MIN_VALUE"] = df2.sum().Y.index
    d3["MAX_VALUE"] = d3["MIN_VALUE"]
    d3["EVENT"] = df2.sum().Y
    d3["NONEVENT"] = df2.count().Y - df2.sum().Y
    
    if len(justmiss.index) > 0:
        d4 = pd.DataFrame({'MIN_VALUE':np.nan},index=[0])
        d4["MAX_VALUE"] = np.nan
        d4["COUNT"] = justmiss.count().Y
        d4["EVENT"] = justmiss.sum().Y
        d4["NONEVENT"] = justmiss.count().Y - justmiss.sum().Y
        d3 = d3.append(d4,ignore_index=True)
    
    d3["EVENT_RATE"] = d3.EVENT/d3.COUNT
    d3["NON_EVENT_RATE"] = d3.NONEVENT/d3.COUNT
    d3["DIST_EVENT"] = d3.EVENT/d3.sum().EVENT
    d3["DIST_NON_EVENT"] = d3.NONEVENT/d3.sum().NONEVENT
    d3["WOE"] = np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["IV"] = (d3.DIST_EVENT-d3.DIST_NON_EVENT)*np.log(d3.DIST_EVENT/d3.DIST_NON_EVENT)
    d3["VAR_NAME"] = "VAR"
    d3 = d3[['VAR_NAME','MIN_VALUE', 'MAX_VALUE', 'COUNT', 'EVENT', 'EVENT_RATE', 'NONEVENT', 'NON_EVENT_RATE', 'DIST_EVENT','DIST_NON_EVENT','WOE', 'IV']]      
    d3 = d3.replace([np.inf, -np.inf], 0)
    d3.IV = d3.IV.sum()
    d3 = d3.reset_index(drop=True)
    
    return(d3)

def data_vars(df1, target):
    
    stack = traceback.extract_stack()
    filename, lineno, function_name, code = stack[-2]
    vars_name = re.compile(r'\((.*?)\).*$').search(code).groups()[0]
    final = (re.findall(r"[\w']+", vars_name))[-1]
    
    x = df1.dtypes.index
    count = -1
    
    for i in x:
        if i.upper() not in (final.upper()):
            if np.issubdtype(df1[i], np.number) and len(Series.unique(df1[i])) > 2:
                conv = mono_bin(target, df1[i])
                conv["VAR_NAME"] = i
                count = count + 1
            else:
                conv = char_bin(target, df1[i])
                conv["VAR_NAME"] = i            
                count = count + 1
                
            if count == 0:
                iv_df = conv
            else:
                iv_df = iv_df.append(conv,ignore_index=True)
    
    iv = pd.DataFrame({'IV':iv_df.groupby('VAR_NAME').IV.max()})
    iv = iv.reset_index()
    return(iv_df,iv)

# %%
final_iv, IV = data_vars(df_socialm[df_socialm.columns.difference(['target'])],df_socialm.target)

# %%
final_iv
# Out:
#                            VAR_NAME  MIN_VALUE  MAX_VALUE  COUNT  EVENT  \
# 0     data_channel_is_entertainment   0.000000   0.000000  32587   7153
# 1     data_channel_is_entertainment   1.000000   1.000000   7057   1185
# 2                            LDA_00   0.000000   0.033387  19822   4288
# 3                            LDA_00   0.033387   0.926994  19822   4050
# 4                            LDA_01   0.000000   0.025012   9911   2199
# ..                              ...        ...        ...    ...    ...
# 156             weekday_is_thursday   1.000000   1.000000   7267   1419
# 157              weekday_is_tuesday   0.000000   0.000000  32254   6927
# 158              weekday_is_tuesday   1.000000   1.000000   7390   1411
# 159            weekday_is_wednesday   0.000000   0.000000  32209   6917
# 160            weekday_is_wednesday   1.000000   1.000000   7435   1421
#
#      EVENT_RATE  NONEVENT  NON_EVENT_RATE  DIST_EVENT  DIST_NON_EVENT  \
# 0      0.219505     25434        0.780495    0.857880        0.812432
# 1      0.167918      5872        0.832082    0.142120        0.187568
# 2      0.216325     15534        0.783675    0.514272        0.496199
# 3      0.204318     15772        0.795682    0.485728        0.503801
# 4      0.221875      7712        0.778125    0.263732        0.246343
# ..          ...       ...             ...         ...             ...
# 156    0.195266      5848        0.804734    0.170185        0.186801
# 157    0.214764     25327        0.785236    0.830775        0.809014
# 158    0.190934      5979        0.809066    0.169225        0.190986
# 159    0.214754     25292        0.785246    0.829575        0.807896
# 160    0.191123      6014        0.808877    0.170425        0.192104
#
#           WOE        IV
# 0    0.054431  0.015084
# 1   -0.277466  0.015084
# 2    0.035776  0.001307
# 3   -0.036533  0.001307
# 4    0.068212  0.002014
# ..        ...       ...
# 156 -0.093161  0.001884
# 157  0.026542  0.003210
# 158 -0.120968  0.003210
# 159  0.026480  0.003170
# 160 -0.119743  0.003170
#
# [161 rows x 12 columns]

# %%
IV = IV.rename(columns={'VAR_NAME':'index'})
IV.sort_values(['IV'],ascending=0)
# Out:
#                              index        IV
# 21                      kw_avg_avg  0.278920
# 24                      kw_max_avg  0.235151
# 46      self_reference_avg_sharess  0.123367
# 3                           LDA_02  0.118766
# 48       self_reference_min_shares  0.112602
# 47       self_reference_max_shares  0.091133
# 15           data_channel_is_world  0.089442
# 19             global_subjectivity  0.051712
# 4                           LDA_03  0.044126
# 20                      is_weekend  0.031919
# 40                        num_imgs  0.029853
# 13          data_channel_is_socmed  0.018736
# 26                      kw_max_min  0.017135
# 56               weekday_is_sunday  0.017047
# 0    data_channel_is_entertainment  0.015084
# 39                       num_hrefs  0.014703
# 41                    num_keywords  0.014516
# 8             average_token_length  0.014156
# 10           avg_positive_polarity  0.012509
# 55             weekday_is_saturday  0.012417
# 23                      kw_avg_min  0.011552
# 22                      kw_avg_max  0.011259
# 31           max_positive_polarity  0.010411
# 17      global_rate_positive_words  0.010375
# 27                      kw_min_avg  0.010004
# 11             data_channel_is_bus  0.008893
# 9            avg_negative_polarity  0.008065
# 18       global_sentiment_polarity  0.007188
# 43                      num_videos  0.006529
# 28                      kw_min_max  0.006282
# 44             rate_negative_words  0.006176
# 50        title_sentiment_polarity  0.005911
# 35                n_non_stop_words  0.004204
# 51              title_subjectivity  0.004066
# 36                n_tokens_content  0.004023
# 34        n_non_stop_unique_tokens  0.003918
# 52                             url  0.003730
# 49                       timedelta  0.003688
# 32           min_negative_polarity  0.003509
# 58              weekday_is_tuesday  0.003210
# 59            weekday_is_wednesday  0.003170
# 12       data_channel_is_lifestyle  0.003025
# 37                  n_tokens_title  0.002980
# 5                           LDA_04  0.002925
# 14            data_channel_is_tech  0.002562
# 2                           LDA_01  0.002014
# 57             weekday_is_thursday  0.001884
# 45             rate_positive_words  0.001403
# 1                           LDA_00  0.001307
# 42                  num_self_hrefs  0.000542
# 29                      kw_min_min  0.000534
# 33           min_positive_polarity  0.000363
# 25                      kw_max_max  0.000279
# 30           max_negative_polarity  0.000154
# 54               weekday_is_monday  0.000028
# 38                 n_unique_tokens  0.000027
# 53               weekday_is_friday  0.000012
# 16      global_rate_negative_words  0.000010
# 6     abs_title_sentiment_polarity  0.000000
# 7           abs_title_subjectivity  0.000000

# %%
#Apply WOE values to your dataframe columns
#The below code snippet can be used to apply the WOE values to your dataframe columns.

transform_vars_list = df_socialm.columns.difference(['target'])
transform_prefix = 'new_' # leave this value blank if you need replace the original column values

# %%
transform_vars_list
# Out:
# Index([' data_channel_is_entertainment', 'LDA_00', 'LDA_01', 'LDA_02',
#        'LDA_03', 'LDA_04', 'abs_title_sentiment_polarity',
#        'abs_title_subjectivity', 'average_token_length',
#        'avg_negative_polarity', 'avg_positive_polarity', 'data_channel_is_bus',
#        'data_channel_is_lifestyle', 'data_channel_is_socmed',
#        'data_channel_is_tech', 'data_channel_is_world',
#        'global_rate_negative_words', 'global_rate_positive_words',
#        'global_sentiment_polarity', 'global_subjectivity', 'is_weekend',
#        'kw_avg_avg', 'kw_avg_max', 'kw_avg_min', 'kw_max_avg', 'kw_max_max',
#        'kw_max_min', 'kw_min_avg', 'kw_min_max', 'kw_min_min',
#        'max_negative_polarity', 'max_positive_polarity',
#        'min_negative_polarity', 'min_positive_polarity',
#        'n_non_stop_unique_tokens', 'n_non_stop_words', 'n_tokens_content',
#        'n_tokens_title', 'n_unique_tokens', 'num_hrefs', 'num_imgs',
#        'num_keywords', 'num_self_hrefs', 'num_videos', 'rate_negative_words',
#        'rate_positive_words', 'self_reference_avg_sharess',
#        'self_reference_max_shares', 'self_reference_min_shares', 'timedelta',
#        'title_sentiment_polarity', 'title_subjectivity', 'url',
#        'weekday_is_friday', 'weekday_is_monday', 'weekday_is_saturday',
#        'weekday_is_sunday', 'weekday_is_thursday', 'weekday_is_tuesday',
#        'weekday_is_wednesday'],
#       dtype='object')

# %%
for var in transform_vars_list:
    small_df=final_iv[final_iv['VAR_NAME']==var]
    transform_dict = dict(zip(small_df.MAX_VALUE,small_df.WOE))
    replace_cmd = ''
    replace_cmd1 = ''
    for i in sorted(transform_dict.items()):
        replace_cmd = replace_cmd + str(i[1]) + str(' if x <= ') + str(i[0]) + ' else '
        replace_cmd1 = replace_cmd1 + str(i[1]) + str(' if x == "') + str(i[0]) + '" else '
    replace_cmd = replace_cmd + '0'
    replace_cmd1 = replace_cmd1 + '0'
    if replace_cmd != '0':
        try:
            df_socialm[transform_prefix + var] = df_socialm[var].apply(lambda x: eval(replace_cmd))
        except:
            df_socialm[transform_prefix + var] = df_socialm[var].apply(lambda x: eval(replace_cmd1))

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

clf.fit(features,labels)

preds = clf.predict(features)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(preds,labels)
print(accuracy)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.979063666633034

# %%
from pandas import DataFrame
VI =DataFrame(clf.feature_importances_, columns = ["RF"], index=features.columns)

# %%
VI =VI.reset_index()
VI.sort_values(['RF'],ascending=0)
# Out:
#                              index        RF
# 21                      kw_avg_avg  0.044777
# 24                      kw_max_avg  0.040287
# 46      self_reference_avg_sharess  0.028873
# 3                           LDA_02  0.028770
# 48       self_reference_min_shares  0.028255
# 1                           LDA_00  0.027639
# 22                      kw_avg_max  0.027518
# 2                           LDA_01  0.027415
# 19             global_subjectivity  0.027203
# 34        n_non_stop_unique_tokens  0.026829
# 4                           LDA_03  0.026767
# 23                      kw_avg_min  0.026761
# 8             average_token_length  0.026529
# 10           avg_positive_polarity  0.026135
# 5                           LDA_04  0.026009
# 49                       timedelta  0.025969
# 36                n_tokens_content  0.025655
# 52                             url  0.025618
# 17      global_rate_positive_words  0.025101
# 26                      kw_max_min  0.024902
# 38                 n_unique_tokens  0.024256
# 18       global_sentiment_polarity  0.024182
# 47       self_reference_max_shares  0.023810
# 27                      kw_min_avg  0.023715
# 9            avg_negative_polarity  0.022611
# 16      global_rate_negative_words  0.021891
# 39                       num_hrefs  0.021504
# 44             rate_negative_words  0.020362
# 45             rate_positive_words  0.019216
# 37                  n_tokens_title  0.018021
# 28                      kw_min_max  0.016250
# 50        title_sentiment_polarity  0.015905
# 40                        num_imgs  0.014993
# 32           min_negative_polarity  0.014232
# 51              title_subjectivity  0.014009
# 6     abs_title_sentiment_polarity  0.013159
# 30           max_negative_polarity  0.012881
# 42                  num_self_hrefs  0.012486
# 7           abs_title_subjectivity  0.011578
# 33           min_positive_polarity  0.011499
# 41                    num_keywords  0.009727
# 31           max_positive_polarity  0.009535
# 43                      num_videos  0.008881
# 20                      is_weekend  0.004597
# 25                      kw_max_max  0.003997
# 29                      kw_min_min  0.003277
# 15           data_channel_is_world  0.003255
# 14            data_channel_is_tech  0.003130
# 56               weekday_is_sunday  0.003118
# 54               weekday_is_monday  0.002994
# 59            weekday_is_wednesday  0.002942
# 53               weekday_is_friday  0.002921
# 58              weekday_is_tuesday  0.002903
# 0    data_channel_is_entertainment  0.002896
# 55             weekday_is_saturday  0.002789
# 57             weekday_is_thursday  0.002773
# 13          data_channel_is_socmed  0.002674
# 11             data_channel_is_bus  0.002139
# 12       data_channel_is_lifestyle  0.001770
# 35                n_non_stop_words  0.000112

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression


model = LogisticRegression()
rfe = RFE(model,20)
fit = rfe.fit(features, labels)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from pandas import DataFrame
Selected = DataFrame(rfe.support_, columns = ["RFE"], index=features.columns)
Selected = Selected.reset_index()

# %%
Selected[Selected['RFE'] == True]
# Out:
#                              index   RFE
# 0    data_channel_is_entertainment  True
# 2                           LDA_01  True
# 3                           LDA_02  True
# 5                           LDA_04  True
# 6     abs_title_sentiment_polarity  True
# 8             average_token_length  True
# 11             data_channel_is_bus  True
# 13          data_channel_is_socmed  True
# 15           data_channel_is_world  True
# 20                      is_weekend  True
# 34        n_non_stop_unique_tokens  True
# 35                n_non_stop_words  True
# 38                 n_unique_tokens  True
# 41                    num_keywords  True
# 50        title_sentiment_polarity  True
# 55             weekday_is_saturday  True
# 56               weekday_is_sunday  True
# 57             weekday_is_thursday  True
# 58              weekday_is_tuesday  True
# 59            weekday_is_wednesday  True

# %%
#Variable Importance using Extratrees Classifier
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier()
model.fit(features, labels)

print(model.feature_importances_)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.00762652 0.02254508 0.02035758 0.02626004 0.02777852 0.02220112
#  0.01822053 0.01763774 0.02083943 0.01908619 0.01970342 0.0036511
#  0.00395426 0.00477426 0.00431412 0.00860507 0.01910015 0.01936254
#  0.01830776 0.02011815 0.00613721 0.02706829 0.02236477 0.02054816
#  0.02543639 0.00946523 0.02106369 0.02441188 0.01699164 0.01192613
#  0.01919712 0.018454   0.01935539 0.01798182 0.02139785 0.00049159
#  0.02146741 0.02182969 0.02081556 0.023117   0.02093393 0.01918523
#  0.01919156 0.0181167  0.01859164 0.01843047 0.0231411  0.02136668
#  0.02374133 0.01965337 0.01728541 0.0183706  0.02093401 0.00771105
#  0.00873168 0.0031392  0.00407077 0.00813264 0.00859431 0.00671393]

# %%
from pandas import DataFrame
FI = DataFrame(model.feature_importances_, columns = ["Extratrees"], index=features.columns)

# %%
FI = FI.reset_index()

# %%
FI.sort_values(['Extratrees'],ascending=0)
# Out:
#                              index  Extratrees
# 4                           LDA_03    0.027779
# 21                      kw_avg_avg    0.027068
# 3                           LDA_02    0.026260
# 24                      kw_max_avg    0.025436
# 27                      kw_min_avg    0.024412
# 48       self_reference_min_shares    0.023741
# 46      self_reference_avg_sharess    0.023141
# 39                       num_hrefs    0.023117
# 1                           LDA_00    0.022545
# 22                      kw_avg_max    0.022365
# 5                           LDA_04    0.022201
# 37                  n_tokens_title    0.021830
# 36                n_tokens_content    0.021467
# 34        n_non_stop_unique_tokens    0.021398
# 47       self_reference_max_shares    0.021367
# 26                      kw_max_min    0.021064
# 52                             url    0.020934
# 40                        num_imgs    0.020934
# 8             average_token_length    0.020839
# 38                 n_unique_tokens    0.020816
# 23                      kw_avg_min    0.020548
# 2                           LDA_01    0.020358
# 19             global_subjectivity    0.020118
# 10           avg_positive_polarity    0.019703
# 49                       timedelta    0.019653
# 17      global_rate_positive_words    0.019363
# 32           min_negative_polarity    0.019355
# 30           max_negative_polarity    0.019197
# 42                  num_self_hrefs    0.019192
# 41                    num_keywords    0.019185
# 16      global_rate_negative_words    0.019100
# 9            avg_negative_polarity    0.019086
# 44             rate_negative_words    0.018592
# 31           max_positive_polarity    0.018454
# 45             rate_positive_words    0.018430
# 51              title_subjectivity    0.018371
# 18       global_sentiment_polarity    0.018308
# 6     abs_title_sentiment_polarity    0.018221
# 43                      num_videos    0.018117
# 33           min_positive_polarity    0.017982
# 7           abs_title_subjectivity    0.017638
# 50        title_sentiment_polarity    0.017285
# 28                      kw_min_max    0.016992
# 29                      kw_min_min    0.011926
# 25                      kw_max_max    0.009465
# 54               weekday_is_monday    0.008732
# 15           data_channel_is_world    0.008605
# 58              weekday_is_tuesday    0.008594
# 57             weekday_is_thursday    0.008133
# 53               weekday_is_friday    0.007711
# 0    data_channel_is_entertainment    0.007627
# 59            weekday_is_wednesday    0.006714
# 20                      is_weekend    0.006137
# 13          data_channel_is_socmed    0.004774
# 14            data_channel_is_tech    0.004314
# 56               weekday_is_sunday    0.004071
# 12       data_channel_is_lifestyle    0.003954
# 11             data_channel_is_bus    0.003651
# 55             weekday_is_saturday    0.003139
# 35                n_non_stop_words    0.000492

# %%
#4.5 Chi Square
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

model = SelectKBest(score_func=chi2, k=5)
fit = model.fit(features.abs(), labels)

# %%
from pandas import DataFrame
pd.options.display.float_format = '{:.2f}'.format
chi_sq = DataFrame(fit.scores_, columns = ["Chi_Square"], index=features.columns)

# %%
chi_sq = chi_sq.reset_index()

# %%
chi_sq.sort_values('Chi_Square',ascending=0)
# Out:
#                              index  Chi_Square
# 47       self_reference_max_shares 24549784.44
# 46      self_reference_avg_sharess 18867109.23
# 48       self_reference_min_shares 15429690.56
# 22                      kw_avg_max  7939598.59
# 24                      kw_max_avg  2209311.85
# 28                      kw_min_max  1662679.78
# 21                      kw_avg_avg   745952.84
# 27                      kw_min_avg   369669.06
# 26                      kw_max_min   326462.29
# 52                             url   204287.77
# 25                      kw_max_max   109927.74
# 23                      kw_avg_min    39268.77
# 49                       timedelta     3410.41
# 40                        num_imgs     3031.58
# 39                       num_hrefs     2696.05
# 36                n_tokens_content     1561.39
# 43                      num_videos      509.44
# 15           data_channel_is_world      396.96
# 3                           LDA_02      224.68
# 4                           LDA_03      215.84
# 20                      is_weekend      201.18
# 13          data_channel_is_socmed      131.71
# 29                      kw_min_min      129.90
# 56               weekday_is_sunday      116.72
# 55             weekday_is_saturday       84.99
# 35                n_non_stop_words       81.54
# 0    data_channel_is_entertainment       76.40
# 38                 n_unique_tokens       69.41
# 41                    num_keywords       56.22
# 11             data_channel_is_bus       46.65
# 34        n_non_stop_unique_tokens       36.97
# 51              title_subjectivity       28.57
# 50        title_sentiment_polarity       28.52
# 6     abs_title_sentiment_polarity       28.52
# 42                  num_self_hrefs       21.99
# 12       data_channel_is_lifestyle       20.02
# 58              weekday_is_tuesday       16.73
# 59            weekday_is_wednesday       16.50
# 14            data_channel_is_tech       14.06
# 8             average_token_length       10.60
# 57             weekday_is_thursday        9.92
# 2                           LDA_01        9.68
# 37                  n_tokens_title        6.17
# 19             global_subjectivity        4.03
# 44             rate_negative_words        3.02
# 18       global_sentiment_polarity        3.00
# 9            avg_negative_polarity        2.75
# 32           min_negative_polarity        2.74
# 1                           LDA_00        2.36
# 31           max_positive_polarity        1.34
# 5                           LDA_04        1.16
# 30           max_negative_polarity        0.70
# 10           avg_positive_polarity        0.61
# 17      global_rate_positive_words        0.25
# 54               weekday_is_monday        0.15
# 53               weekday_is_friday        0.07
# 45             rate_positive_words        0.05
# 33           min_positive_polarity        0.05
# 7           abs_title_subjectivity        0.01
# 16      global_rate_negative_words        0.00

# %%
#L1 feature selection
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
lsvc = LinearSVC(C=0.01, penalty="l1", dual=False).fit(features, labels)
model = SelectFromModel(lsvc,prefit=True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
from pandas import DataFrame
l1 = DataFrame(model.get_support(), columns = ["L1"], index=features.columns)
l1 = l1.reset_index()

# %%
l1[l1['L1'] == True]
# Out:
#                              index    L1
# 0    data_channel_is_entertainment  True
# 1                           LDA_00  True
# 3                           LDA_02  True
# 7           abs_title_subjectivity  True
# 8             average_token_length  True
# 11             data_channel_is_bus  True
# 12       data_channel_is_lifestyle  True
# 13          data_channel_is_socmed  True
# 14            data_channel_is_tech  True
# 19             global_subjectivity  True
# 20                      is_weekend  True
# 21                      kw_avg_avg  True
# 23                      kw_avg_min  True
# 24                      kw_max_avg  True
# 26                      kw_max_min  True
# 27                      kw_min_avg  True
# 29                      kw_min_min  True
# 32           min_negative_polarity  True
# 35                n_non_stop_words  True
# 36                n_tokens_content  True
# 37                  n_tokens_title  True
# 39                       num_hrefs  True
# 40                        num_imgs  True
# 41                    num_keywords  True
# 42                  num_self_hrefs  True
# 43                      num_videos  True
# 49                       timedelta  True
# 50        title_sentiment_polarity  True
# 51              title_subjectivity  True
# 52                             url  True
# 54               weekday_is_monday  True
# 56               weekday_is_sunday  True
# 57             weekday_is_thursday  True
# 58              weekday_is_tuesday  True
# 59            weekday_is_wednesday  True

# %%
#4.7 Combine all together
from functools import reduce
dfs = [IV, VI, Selected, FI, chi_sq, l1]
final_results = reduce(lambda left,right: pd.merge(left,right,on='index'), dfs)

# %%
#4.8 Vote each variable
columns = ['IV', 'RF', 'Extratrees', 'Chi_Square']

score_table = pd.DataFrame({},[])
score_table['index'] = final_results['index']

for i in columns:
    score_table[i] = final_results['index'].isin(list(final_results.nlargest(5,i)['index'])).astype(int)
    
score_table['RFE'] = final_results['RFE'].astype(int)
score_table['L1'] = final_results['L1'].astype(int)

# %%
score_table['final_score'] = score_table.sum(axis=1)

# %%
score_table.sort_values('final_score',ascending=0)
# Out:
#                              index  IV  RF  Extratrees  Chi_Square  RFE  L1  \
# 3                           LDA_02   1   1           1           0    1   1
# 24                      kw_max_avg   1   1           1           1    0   1
# 21                      kw_avg_avg   1   1           1           0    0   1
# 48       self_reference_min_shares   1   1           0           1    0   0
# 46      self_reference_avg_sharess   1   1           0           1    0   0
# 0    data_channel_is_entertainment   0   0           0           0    1   1
# 20                      is_weekend   0   0           0           0    1   1
# 58              weekday_is_tuesday   0   0           0           0    1   1
# 57             weekday_is_thursday   0   0           0           0    1   1
# 56               weekday_is_sunday   0   0           0           0    1   1
# 50        title_sentiment_polarity   0   0           0           0    1   1
# 41                    num_keywords   0   0           0           0    1   1
# 35                n_non_stop_words   0   0           0           0    1   1
# 27                      kw_min_avg   0   0           1           0    0   1
# 59            weekday_is_wednesday   0   0           0           0    1   1
# 13          data_channel_is_socmed   0   0           0           0    1   1
# 8             average_token_length   0   0           0           0    1   1
# 11             data_channel_is_bus   0   0           0           0    1   1
# 15           data_channel_is_world   0   0           0           0    1   0
# 49                       timedelta   0   0           0           0    0   1
# 39                       num_hrefs   0   0           0           0    0   1
# 40                        num_imgs   0   0           0           0    0   1
# 42                  num_self_hrefs   0   0           0           0    0   1
# 43                      num_videos   0   0           0           0    0   1
# 47       self_reference_max_shares   0   0           0           1    0   0
# 7           abs_title_subjectivity   0   0           0           0    0   1
# 6     abs_title_sentiment_polarity   0   0           0           0    1   0
# 36                n_tokens_content   0   0           0           0    0   1
# 51              title_subjectivity   0   0           0           0    0   1
# 52                             url   0   0           0           0    0   1
# 54               weekday_is_monday   0   0           0           0    0   1
# 55             weekday_is_saturday   0   0           0           0    1   0
# 5                           LDA_04   0   0           0           0    1   0
# 4                           LDA_03   0   0           1           0    0   0
# 2                           LDA_01   0   0           0           0    1   0
# 38                 n_unique_tokens   0   0           0           0    1   0
# 37                  n_tokens_title   0   0           0           0    0   1
# 12       data_channel_is_lifestyle   0   0           0           0    0   1
# 34        n_non_stop_unique_tokens   0   0           0           0    1   0
# 32           min_negative_polarity   0   0           0           0    0   1
# 19             global_subjectivity   0   0           0           0    0   1
# 14            data_channel_is_tech   0   0           0           0    0   1
# 22                      kw_avg_max   0   0           0           1    0   0
# 1                           LDA_00   0   0           0           0    0   1
# 29                      kw_min_min   0   0           0           0    0   1
# 26                      kw_max_min   0   0           0           0    0   1
# 23                      kw_avg_min   0   0           0           0    0   1
# 16      global_rate_negative_words   0   0           0           0    0   0
# 17      global_rate_positive_words   0   0           0           0    0   0
# 18       global_sentiment_polarity   0   0           0           0    0   0
# 53               weekday_is_friday   0   0           0           0    0   0
# 28                      kw_min_max   0   0           0           0    0   0
# 25                      kw_max_max   0   0           0           0    0   0
# 10           avg_positive_polarity   0   0           0           0    0   0
# 45             rate_positive_words   0   0           0           0    0   0
# 44             rate_negative_words   0   0           0           0    0   0
# 31           max_positive_polarity   0   0           0           0    0   0
# 9            avg_negative_polarity   0   0           0           0    0   0
# 33           min_positive_polarity   0   0           0           0    0   0
# 30           max_negative_polarity   0   0           0           0    0   0
#
#     final_score
# 3             5
# 24            5
# 21            4
# 48            3
# 46            3
# 0             2
# 20            2
# 58            2
# 57            2
# 56            2
# 50            2
# 41            2
# 35            2
# 27            2
# 59            2
# 13            2
# 8             2
# 11            2
# 15            1
# 49            1
# 39            1
# 40            1
# 42            1
# 43            1
# 47            1
# 7             1
# 6             1
# 36            1
# 51            1
# 52            1
# 54            1
# 55            1
# 5             1
# 4             1
# 2             1
# 38            1
# 37            1
# 12            1
# 34            1
# 32            1
# 19            1
# 14            1
# 22            1
# 1             1
# 29            1
# 26            1
# 23            1
# 16            0
# 17            0
# 18            0
# 53            0
# 28            0
# 25            0
# 10            0
# 45            0
# 44            0
# 31            0
# 9             0
# 33            0
# 30            0

# %%
#4.9 Multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calculate_vif(features):
    vif = pd.DataFrame()
    vif["Features"] = features.columns
    vif["VIF"] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]    
    return(vif)

# %%
features = features[list(score_table[score_table['final_score'] >= 2]['index'])]

# %%
vif = calculate_vif(features)
while vif['VIF'][vif['VIF'] > 10].any():
    remove = vif.sort_values('VIF',ascending=0)['Features'][:1]
    features.drop(remove,axis=1,inplace=True)
    vif = calculate_vif(features)

# %%
list(vif['Features'])
# Out:
# [' data_channel_is_entertainment',
#  'LDA_02',
#  'data_channel_is_bus',
#  'data_channel_is_socmed',
#  'is_weekend',
#  'kw_max_avg',
#  'kw_min_avg',
#  'n_non_stop_words',
#  'num_keywords',
#  'self_reference_avg_sharess',
#  'self_reference_min_shares',
#  'title_sentiment_polarity',
#  'weekday_is_sunday',
#  'weekday_is_thursday',
#  'weekday_is_tuesday',
#  'weekday_is_wednesday']

# %%
#Descriptive Stats and Visualization - For selected variables
final_vars = list(vif['Features']) + ['target']

# %%
df1 = df_socialm[final_vars].fillna(0)

# %%
df1.describe()
# Out:
#         data_channel_is_entertainment   LDA_02  data_channel_is_bus  \
# count                        39644.00 39644.00             39644.00
# mean                             0.18     0.22                 0.16
# std                              0.38     0.28                 0.36
# min                              0.00     0.00                 0.00
# 25%                              0.00     0.03                 0.00
# 50%                              0.00     0.04                 0.00
# 75%                              0.00     0.33                 0.00
# max                              1.00     0.92                 1.00
#
#        data_channel_is_socmed  is_weekend  kw_max_avg  kw_min_avg  \
# count                39644.00    39644.00    39644.00    39644.00
# mean                     0.06        0.13     5657.21     1117.15
# std                      0.23        0.34     6098.87     1137.46
# min                      0.00        0.00        0.00       -1.00
# 25%                      0.00        0.00     3562.10        0.00
# 50%                      0.00        0.00     4355.69     1023.64
# 75%                      0.00        0.00     6019.95     2056.78
# max                      1.00        1.00   298400.00     3613.04
#
#        n_non_stop_words  num_keywords  self_reference_avg_sharess  \
# count          39644.00      39644.00                    39644.00
# mean               1.00          7.22                     6401.70
# std                5.23          1.91                    24211.33
# min                0.00          1.00                        0.00
# 25%                1.00          6.00                      981.19
# 50%                1.00          7.00                     2200.00
# 75%                1.00          9.00                     5200.00
# max             1042.00         10.00                   843300.00
#
#        self_reference_min_shares  title_sentiment_polarity  weekday_is_sunday  \
# count                   39644.00                  39644.00           39644.00
# mean                     3998.76                      0.07               0.07
# std                     19738.67                      0.27               0.25
# min                         0.00                     -1.00               0.00
# 25%                       639.00                      0.00               0.00
# 50%                      1200.00                      0.00               0.00
# 75%                      2600.00                      0.15               0.00
# max                    843300.00                      1.00               1.00
#
#        weekday_is_thursday  weekday_is_tuesday  weekday_is_wednesday   target
# count             39644.00            39644.00              39644.00 39644.00
# mean                  0.18                0.19                  0.19     0.21
# std                   0.39                0.39                  0.39     0.41
# min                   0.00                0.00                  0.00     0.00
# 25%                   0.00                0.00                  0.00     0.00
# 50%                   0.00                0.00                  0.00     0.00
# 75%                   0.00                0.00                  0.00     0.00
# max                   1.00                1.00                  1.00     1.00

# %%
bar_color = '#058caa'
num_color = '#ed8549'

final_iv,_ = data_vars(df1,df1['target'])
final_iv = final_iv[(final_iv.VAR_NAME != 'target')]
grouped = final_iv.groupby(['VAR_NAME'])
for key, group in grouped:
    ax = group.plot('MIN_VALUE','EVENT_RATE',kind='bar',color=bar_color,linewidth=1.0,edgecolor=['black'])
    ax.set_title(str(key) + " vs " + str('target'))
    ax.set_xlabel(key)
    ax.set_ylabel(str('target') + " %")
    rects = ax.patches
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.01*height, str(round(height*100,1)) + '%', 
                ha='center', va='bottom', color=num_color, fontweight='bold')

# %%
#5. Model
from sklearn.model_selection import train_test_split

train, test = train_test_split(df1, test_size = 0.4)
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

features_train = train[list(vif['Features'])]
label_train = train['target']
features_test = test[list(vif['Features'])]
label_test = test['target']

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9778861515176995 0.7763904653802497 0.9992810284254232 0.6221226265656196

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0     1
# ACTUAL
# 0       18778     8
# 1         518  4482

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0    1
# ACTUAL
# 0       11950  570
# 1        2976  362

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.7886151517699487 0.7882456804136714 0.567449515596721 0.5672247591391222
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0   1
# ACTUAL
# 0       18726  60
# 1        4968  32

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0   1
# ACTUAL
# 0       12476  44
# 1        3314  24

# %%
#Neural Network
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.5351467249642647 0.5288182620759239 0.6087001809858406 0.59552764707684
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED       0     1
# ACTUAL
# 0       9634  9152
# 1       1905  3095

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED       0     1
# ACTUAL
# 0       6337  6183
# 1       1289  2049

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB 
clf = GaussianNB()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.7841587488438577 0.7804262832639677 0.6564204833386564 0.6512785295474515

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0    1
# ACTUAL
# 0       18373  413
# 1        4721  279

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0    1
# ACTUAL
# 0       12202  318
# 1        3164  174

# %%
#gradient boosting
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.7973177499369377 0.7880565014503721 0.726980794208453 0.6938479977871235

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0    1
# ACTUAL
# 0       18564  222
# 1        4599  401

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED        0    1
# ACTUAL
# 0       12288  232
# 1        3129  209

# %%
#6. Performance Tuning
#Random Forest - Hyper parameter tuning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 10, cv = 2, verbose=2, random_state=42, n_jobs = -1)
rf_random.fit(features_train, label_train)

print(rf_random.best_params_)
# Out:
# Fitting 2 folds for each of 10 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  20 | elapsed:    3.7s remaining:    5.6s
# {'n_estimators': 10, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 3, 'bootstrap': False}
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    9.9s finished

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(**rf_random.best_params_)

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.7897923148070294 0.7895068735023332 0.6842134461833279 0.6689872716535509

# %%
#Gradient Boosting - Hyper parameter tuning
from sklearn.model_selection import train_test_split
from sklearn import metrics   
from sklearn.model_selection import learning_curve,GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 500, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(3, 10, num = 1)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

gb = GradientBoostingClassifier()

gf_tune = GridSearchCV(estimator = gb, param_grid = grid, cv = 2, verbose=2, n_jobs = -1)
gf_tune.fit(features_train, label_train)

print(gf_tune.best_params_)
# Out:
# Fitting 2 folds for each of 360 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  1.3min
# /opt/anaconda3/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed: 150.4min

# %%
print(gf_tune.best_params_)
# Out:
# {'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 10}

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(**gf_tune.best_params_)

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.7883208610106786 0.7917139614074915 0.6848818814403385 0.6813156956500088

# %%
#7. Final Model and Model Performance
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

clf.fit(features_train,label_train)

pred_train = clf.predict(features_train)
pred_test = clf.predict(features_test)

from sklearn.metrics import accuracy_score
accuracy_train = accuracy_score(pred_train,label_train)
accuracy_test = accuracy_score(pred_test,label_test)

from sklearn import metrics
fpr, tpr, _ = metrics.roc_curve(np.array(label_train), clf.predict_proba(features_train)[:,1])
auc_train = metrics.auc(fpr,tpr)

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), clf.predict_proba(features_test)[:,1])
auc_test = metrics.auc(fpr,tpr)

print(accuracy_train,accuracy_test,auc_train,auc_test)
# Out:
# 0.9745415972116988 0.9740909090909091 0.9985328510082223 0.9983792328827004
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
pd.crosstab(label_train,pd.Series(pred_train),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED       0     1
# ACTUAL
# 0       3871   112
# 1         56  2560

# %%
pd.crosstab(label_test,pd.Series(pred_test),rownames=['ACTUAL'],colnames=['PRED'])
# Out:
# PRED       0     1
# ACTUAL
# 0       2558    69
# 1         45  1728

# %%
#from bokeh.io import Histogram
from ipywidgets import interact
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook
output_notebook()

from sklearn import metrics
preds = clf.predict_proba(features_train)[:,1]

fpr, tpr, _ = metrics.roc_curve(np.array(label_train), preds)
auc = metrics.auc(fpr,tpr)

p = figure(title="ROC Curve - Train data")
r = p.line(fpr,tpr,color='#0077bc',legend = 'AUC = '+ str(round(auc,3)), line_width=2)
s = p.line([0,1],[0,1], color= '#d15555',line_dash='dotdash',line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b15d0efc-8816-4c36-9dc9-156beb2624ac" data-root-id="1002"></div>

# %%
#from bokeh.charts import Histogram
from ipywidgets import interact
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook
output_notebook()

from sklearn import metrics
preds = clf.predict_proba(features_test)[:,1]

fpr, tpr, _ = metrics.roc_curve(np.array(label_test), preds)
auc = metrics.auc(fpr,tpr)

p = figure(title="ROC Curve - Test data")
r = p.line(fpr,tpr,color='#0077bc',legend = 'AUC = '+ str(round(auc,3)), line_width=2)
s = p.line([0,1],[0,1], color= '#d15555',line_dash='dotdash',line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1257">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5254f28a-fe85-4089-9800-a5030c7838a3" data-root-id="1258"></div>

# %%
#Decile Plots and KS statistic
from collections import OrderedDict
import pandas as pd
import sys
# %matplotlib inline
    
def plot_pandas_style(styler):
    from IPython.core.display import HTML
    html = '\n'.join([line.lstrip() for line in styler.render().split('\n')])
    return HTML(html)

def highlight_max(s,color='yellow'):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: {}'.format(color) if v else '' for v in is_max]

def decile_labels(agg1,label,color='skyblue'):
    agg_dummy = pd.DataFrame(OrderedDict((('TOTAL',0),('TARGET',0),('NONTARGET',0),('PCT_TAR',0),('CUM_TAR',0),('CUM_NONTAR',0),('DIST_TAR',0),('DIST_NONTAR',0),('SPREAD',0))),index=[0])
    agg1 = agg1.append(agg_dummy).sort_index()
    agg1.index.name = label
    agg1 = agg1.style.apply(highlight_max, color = 'yellow', subset=['SPREAD'])
    agg1.bar(subset=['TARGET'], color='{}'.format(color))
    agg1.bar(subset=['TOTAL'], color='{}'.format(color))
    agg1.bar(subset=['PCT_TAR'], color='{}'.format(color))
    return(agg1)

def deciling(data,decile_by,target,nontarget):
    inputs = list(decile_by)
    inputs.extend((target,nontarget))
    decile = data[inputs]
    grouped = decile.groupby(decile_by)
    agg1 = pd.DataFrame({},index=[])
    agg1['TOTAL'] = grouped.sum()[nontarget] + grouped.sum()[target]
    agg1['TARGET'] = grouped.sum()[target]
    agg1['NONTARGET'] = grouped.sum()[nontarget]
    agg1['PCT_TAR'] = grouped.mean()[target]*100
    agg1['CUM_TAR'] = grouped.sum()[target].cumsum()
    agg1['CUM_NONTAR'] = grouped.sum()[nontarget].cumsum()
    agg1['DIST_TAR'] = agg1['CUM_TAR']/agg1['TARGET'].sum()*100
    agg1['DIST_NONTAR'] = agg1['CUM_NONTAR']/agg1['NONTARGET'].sum()*100
    agg1['SPREAD'] = (agg1['DIST_TAR'] - agg1['DIST_NONTAR'])
    agg1 = decile_labels(agg1,'DECILE',color='skyblue')
    return(plot_pandas_style(agg1))

# %%
def scoring(features,clf,target):
    score = pd.DataFrame(clf.predict_proba(features)[:,1], columns = ['SCORE'])
    score['DECILE'] = pd.qcut(score['SCORE'].rank(method = 'first'),10,labels=range(10,0,-1))
    score['DECILE'] = score['DECILE'].astype(float)
    score['TARGET'] = target
    score['NONTARGET'] = 1 - target
    return(score)

# %%
scores_train = scoring(features_train,clf,label_train)
scores_test = scoring(features_test,clf,label_test)

# %%
deciling(scores_train,['DECILE'],'TARGET','NONTARGET')
# Out:
# <style  type="text/css" >
# #T_5f2d168a_6419_11ea_b01a_acde48001122row0_col0 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row0_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row0_col3 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row1_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row1_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row1_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row2_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row2_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row2_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row3_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row3_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row3_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row4_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row4_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 86.4%, transparent 86.4%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row4_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 86.4%, transparent 86.4%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row4_col8 {
# background-color:  yellow;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row5_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 99.8%, transparent 99.8%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row5_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 10.0%, transparent 10.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row5_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 10.0%, transparent 10.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row6_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row6_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row6_col3 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row7_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row7_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row7_col3 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row8_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row8_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row8_col3 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row9_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row9_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row9_col3 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row10_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row10_col1 {
# width:  10em;
# height:  80%;
# }    #T_5f2d168a_6419_11ea_b01a_acde48001122row10_col3 {
# width:  10em;
# height:  80%;
# }</style><table id="T_5f2d168a_6419_11ea_b01a_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TOTAL</th>        <th class="col_heading level0 col1" >TARGET</th>        <th class="col_heading level0 col2" >NONTARGET</th>        <th class="col_heading level0 col3" >PCT_TAR</th>        <th class="col_heading level0 col4" >CUM_TAR</th>        <th class="col_heading level0 col5" >CUM_NONTAR</th>        <th class="col_heading level0 col6" >DIST_TAR</th>        <th class="col_heading level0 col7" >DIST_NONTAR</th>        <th class="col_heading level0 col8" >SPREAD</th>    </tr>    <tr>        <th class="index_name level0" >DECILE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
# <tr>
# <th id="T_5f2d168a_6419_11ea_b01a_acde48001122level0_row0" class="row_heading level0 row0" >0.0</th>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col0" class="data row0 col0" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col1" class="data row0 col1" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col2" class="data row0 col2" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col3" class="data row0 col3" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col4" class="data row0 col4" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col5" class="data row0 col5" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col6" class="data row0 col6" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col7" class="data row0 col7" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row0_col8" class="data row0 col8" >0</td>
# </tr>
# <tr>
# <th id="T_5f2d168a_6419_11ea_b01a_acde48001122level0_row1" class="row_heading level0 row1" >1.0</th>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col0" class="data row1 col0" >660</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col1" class="data row1 col1" >660</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col2" class="data row1 col2" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col3" class="data row1 col3" >100</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col4" class="data row1 col4" >660</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col5" class="data row1 col5" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col6" class="data row1 col6" >25.2294</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col7" class="data row1 col7" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row1_col8" class="data row1 col8" >25.2294</td>
# </tr>
# <tr>
# <th id="T_5f2d168a_6419_11ea_b01a_acde48001122level0_row2" class="row_heading level0 row2" >2.0</th>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col0" class="data row2 col0" >660</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col1" class="data row2 col1" >660</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col2" class="data row2 col2" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col3" class="data row2 col3" >100</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col4" class="data row2 col4" >1320</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col5" class="data row2 col5" >0</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col6" class="data row2 col6" >50.4587</td>
# <td id="T_5f2d168a_6419_11ea_b01a_acde48001122row2_col7" class="data row2 col7" >0</td>
# <td id="T_5f2d168a_6419_

# %%
deciling(scores_test,['DECILE'],'TARGET','NONTARGET')
# Out:
# <style  type="text/css" >
# #T_67644742_6419_11ea_b01a_acde48001122row0_col0 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row0_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row0_col3 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row1_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row1_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row1_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row2_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row2_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row2_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row3_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row3_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row3_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row4_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row4_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 89.5%, transparent 89.5%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row4_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 89.5%, transparent 89.5%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row4_col8 {
# background-color:  yellow;
# }    #T_67644742_6419_11ea_b01a_acde48001122row5_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row5_col1 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 13.4%, transparent 13.4%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row5_col3 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 13.4%, transparent 13.4%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row6_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row6_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row6_col3 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row7_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row7_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row7_col3 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row8_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row8_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row8_col3 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row9_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row9_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row9_col3 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row10_col0 {
# width:  10em;
# height:  80%;
# background:  linear-gradient(90deg,skyblue 100.0%, transparent 100.0%);
# }    #T_67644742_6419_11ea_b01a_acde48001122row10_col1 {
# width:  10em;
# height:  80%;
# }    #T_67644742_6419_11ea_b01a_acde48001122row10_col3 {
# width:  10em;
# height:  80%;
# }</style><table id="T_67644742_6419_11ea_b01a_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TOTAL</th>        <th class="col_heading level0 col1" >TARGET</th>        <th class="col_heading level0 col2" >NONTARGET</th>        <th class="col_heading level0 col3" >PCT_TAR</th>        <th class="col_heading level0 col4" >CUM_TAR</th>        <th class="col_heading level0 col5" >CUM_NONTAR</th>        <th class="col_heading level0 col6" >DIST_TAR</th>        <th class="col_heading level0 col7" >DIST_NONTAR</th>        <th class="col_heading level0 col8" >SPREAD</th>    </tr>    <tr>        <th class="index_name level0" >DECILE</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
# <tr>
# <th id="T_67644742_6419_11ea_b01a_acde48001122level0_row0" class="row_heading level0 row0" >0.0</th>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col0" class="data row0 col0" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col1" class="data row0 col1" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col2" class="data row0 col2" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col3" class="data row0 col3" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col4" class="data row0 col4" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col5" class="data row0 col5" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col6" class="data row0 col6" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col7" class="data row0 col7" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row0_col8" class="data row0 col8" >0</td>
# </tr>
# <tr>
# <th id="T_67644742_6419_11ea_b01a_acde48001122level0_row1" class="row_heading level0 row1" >1.0</th>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col0" class="data row1 col0" >440</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col1" class="data row1 col1" >440</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col2" class="data row1 col2" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col3" class="data row1 col3" >100</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col4" class="data row1 col4" >440</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col5" class="data row1 col5" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col6" class="data row1 col6" >24.8167</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col7" class="data row1 col7" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row1_col8" class="data row1 col8" >24.8167</td>
# </tr>
# <tr>
# <th id="T_67644742_6419_11ea_b01a_acde48001122level0_row2" class="row_heading level0 row2" >2.0</th>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col0" class="data row2 col0" >440</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col1" class="data row2 col1" >440</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col2" class="data row2 col2" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col3" class="data row2 col3" >100</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col4" class="data row2 col4" >880</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col5" class="data row2 col5" >0</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col6" class="data row2 col6" >49.6334</td>
# <td id="T_67644742_6419_11ea_b01a_acde48001122row2_col7" class="data row2 col7" >0</td>
# <td id="T_67644742_6419

# %%
#Lift chart, Actual vs predicted and Gains chart
from collections import OrderedDict
import pandas as pd
import matplotlib.pyplot as plt

def plots(agg1,target,type):

    plt.figure(1,figsize=(20, 5))

    plt.subplot(131)
    plt.plot(agg1['DECILE'],agg1['ACTUAL'],label='Actual')
    plt.plot(agg1['DECILE'],agg1['PRED'],label='Pred')
    plt.xticks(range(10,110,10))
    plt.legend(fontsize=15)
    plt.grid(True)
    plt.title('Actual vs Predicted', fontsize=20)
    plt.xlabel("Population %",fontsize=15)
    plt.ylabel(str(target) + " " + str(type) + " %",fontsize=15)

    plt.subplot(132)
    X = agg1['DECILE'].tolist()
    X.append(0)
    Y = agg1['DIST_TAR'].tolist()
    Y.append(0)
    plt.plot(sorted(X),sorted(Y))
    plt.plot([0, 100], [0, 100],'r--')
    plt.xticks(range(0,110,10))
    plt.yticks(range(0,110,10))
    plt.grid(True)
    plt.title('Gains Chart', fontsize=20)
    plt.xlabel("Population %",fontsize=15)
    plt.ylabel(str(target) + str(" DISTRIBUTION") + " %",fontsize=15)
    plt.annotate(round(agg1[agg1['DECILE'] == 30].DIST_TAR.item(),2),xy=[30,30], 
            xytext=(25, agg1[agg1['DECILE'] == 30].DIST_TAR.item() + 5),fontsize = 13)
    plt.annotate(round(agg1[agg1['DECILE'] == 50].DIST_TAR.item(),2),xy=[50,50], 
            xytext=(45, agg1[agg1['DECILE'] == 50].DIST_TAR.item() + 5),fontsize = 13)

    plt.subplot(133)
    plt.plot(agg1['DECILE'],agg1['LIFT'])
    plt.xticks(range(10,110,10))
    plt.grid(True)
    plt.title('Lift Chart', fontsize=20)
    plt.xlabel("Population %",fontsize=15)
    plt.ylabel("Lift",fontsize=15)

    plt.tight_layout()

# %%
def gains(data,decile_by,target,score):
    inputs = list(decile_by)
    inputs.extend((target,score))
    decile = data[inputs]
    grouped = decile.groupby(decile_by)
    agg1 = pd.DataFrame({},index=[])
    agg1['ACTUAL'] = grouped.mean()[target]*100
    agg1['PRED'] = grouped.mean()[score]*100
    agg1['DIST_TAR'] = grouped.sum()[target].cumsum()/grouped.sum()[target].sum()*100
    agg1.index.name = 'DECILE'
    agg1 = agg1.reset_index()
    agg1['DECILE'] = agg1['DECILE']*10
    agg1['LIFT'] = agg1['DIST_TAR']/agg1['DECILE']
    plots(agg1,target,'Distribution')

# %%
lift_train = pd.concat([features_train,scores_train],axis=1)
lift_test = pd.concat([features_test,scores_test],axis=1)

# %%
gains(lift_train,['DECILE'],'TARGET','SCORE')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: `item` has been deprecated and will be removed in a future version

# %%
gains(lift_test,['DECILE'],'TARGET','SCORE')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: `item` has been deprecated and will be removed in a future version
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: `item` has been deprecated and will be removed in a future version

# %%
#Save Model for future use
import pandas
from sklearn.externals import joblib

filename = 'final_model.model'
i = [d,clf]
joblib.dump(i,filename)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['final_model.model']

# %%
#Score New data
# Use the code to load the model
filename = 'final_model.model'

from sklearn.externals import joblib
d,clf=joblib.load(filename)

# %%
def score_new(features,clf):
    score = pd.DataFrame(clf.predict_proba(features)[:,1], columns = ['SCORE'])
    score['DECILE'] = pd.qcut(score['SCORE'].rank(method = 'first'),10,labels=range(10,0,-1))
    score['DECILE'] = score['DECILE'].astype(float)
    return(score)

# %%
scores = score_new(features,clf)
scores
# Out:
#        SCORE  DECILE
# 0       0.94    3.00
# 1       0.01    8.00
# 2       0.01    8.00
# 3       0.01    8.00
# 4       0.85    4.00
# ...      ...     ...
# 10994   0.01   10.00
# 10995   0.01   10.00
# 10996   0.01   10.00
# 10997   0.99    3.00
# 10998   0.01   10.00
#
# [10999 rows x 2 columns]
