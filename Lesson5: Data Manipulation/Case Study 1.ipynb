# %%
import numpy as np
import pandas as pd
df=pd.read_csv('HollywoodMovies.csv')
df
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
#Question 1
df1=df.loc[:,['Movie','Story','RottenTomatoes']]
df2=pd.DataFrame(df1)
df2
# Out:
#                                          Movie          Story  RottenTomatoes
# 0                                 Spider-Man 3  Metamorphosis            61.0
# 1                              Shrek the Third          Quest            42.0
# 2                                 Transformers  Monster Force            57.0
# 3     Pirates of the Caribbean: At World's End         Rescue            45.0
# 4    Harry Potter and the Order of the Phoenix          Quest            78.0
# ..                                         ...            ...             ...
# 965                                The Canyons            NaN            22.0
# 966                                   The Call            NaN            43.0
# 967                        The English Teacher            NaN            42.0
# 968                       John Dies at the End            NaN            61.0
# 969                                   Lovelace            NaN            55.0
#
# [970 rows x 3 columns]

# %%
#Question 2
df1=df.loc[:,['WorldGross','Genre']]
df2=pd.DataFrame(df1)
df_nn=df2[df2.Genre.notnull()]
df_notnull_wg=df_nn[df_notnull_genre.WorldGross.notnull()]
df_final= df_notnull_wg
series_genre = df_final['WorldGross'].groupby(df_final['Genre']).sum()
df_new=pd.DataFrame(series_genre)
genre=df_new.sort_values(by='WorldGross', ascending=False).head(10)  
genre
# Out:
#            WorldGross
# Genre
# Action      40508.804
# Comedy      17840.217
# Animation   17383.285
# Drama        8690.208
# Adventure    7168.277
# Thriller     6555.977
# Horror       4239.239
# Romance      2874.960
# Fantasy      1957.708
# Biography    1663.770

# %%
#Question 3
df1=df.loc[:,['Movie','Budget']]
df_raw=pd.DataFrame(df1)
df2=df_raw[df_raw.Budget.notnull()]
df3=df2.sort_values(by='Budget', ascending=False).head(5)
df3
# Out:
#                                         Movie  Budget
# 3    Pirates of the Caribbean: At World's End   300.0
# 468                                   Tangled   260.0
# 0                                Spider-Man 3   258.0
# 778                     The Dark Knight Rises   250.0
# 241    Harry Potter and the Half-Blood Prince   250.0

# %%
#Question 4
import matplotlib.pyplot as plt

s_data=df.loc[:,['Movie','RottenTomatoes','Profitability']]
data=pd.DataFrame(s_data)
sortdata=s_data.sort_index(by=['RottenTomatoes'],ascending=False)
s_s_data=sortdata.iloc[:10]
fig1, ax1 = plt.subplots()
ax1.axis('equal')
plt.pie(s_s_data['Profitability'],labels=s_s_data['Movie'])
movies=list(s_s_data['Movie'])
plt.legend(movies,loc=2)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: by argument to sort_index is deprecated, please use .sort_values(by=...)

# %%
#Question 5
# 5.1
data={'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
'age': [42, 52, 36, 24, 73],
'preTestScore': [4, 24, 31, ".", "."],
'postTestScore': ["25,000", "94,000", 57, 62, 70]}
df=pd.DataFrame(data)
print(df)
#5.2
file_path='example.csv'
df.to_csv(file_path,sep=',')
#5.3
data2=pd.read_csv('example.csv')
df1=pd.DataFrame(data2)
print(df1)
#5.4
data3=pd.read_csv('example.csv', header=None)
df2=pd.DataFrame(data3)
print(df2)
#5.5
data4=pd.read_csv('example.csv',usecols=[1,2])
df3=pd.DataFrame(data4)
print(df3)
#5.6
data5=pd.read_csv('example.csv')
df4=pd.DataFrame(data5)
print(df4.isnull())
#5.7
data6=pd.read_csv('example.csv', skiprows=3)
df5=pd.DataFrame(data6)
print(df5)
#5.8
data7=pd.read_csv("example.csv", index_col=4).filter(regex='\d{3}')
# Out:
#   first_name last_name  age preTestScore postTestScore
# 0      Jason    Miller   42            4        25,000
# 1      Molly  Jacobson   52           24        94,000
# 2       Tina         .   36           31            57
# 3       Jake    Milner   24            .            62
# 4        Amy     Cooze   73            .            70
#    Unnamed: 0 first_name last_name  age preTestScore postTestScore
# 0           0      Jason    Miller   42            4        25,000
# 1           1      Molly  Jacobson   52           24        94,000
# 2           2       Tina         .   36           31            57
# 3           3       Jake    Milner   24            .            62
# 4           4        Amy     Cooze   73            .            70
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# ...

# %%
#Question 6
#6.1
data='Amit', 'Bob', 'Kate', 'A', 'b', 'np.nan', 'Car', 'dog', 'cat'
df=pd.Series(data)
print("a)", 'Series elements in lower case',df.str.lower()) 
print("b)", 'Series elements in UPPER case',df.str.upper())
print("c)")
for i in range(len(df)):                            
    print('Length of',df[i],'=',len(df[i]))
#6.2
data=' Atul', 'John ', ' jack ', 'Sam'
df=pd.Series(data)
print('a)') 
for i in range(len(df)):
    print(df[i].strip())
print('b)') 
for i in range(len(df)):
    print(df[i].lstrip())
print('c)') 
for i in range(len(df)):
    print(df[i].rstrip())
#6.3
print('a)') 
data=['India_is_big', 'Population_is_huge', 'Has_diverse_culture']
output_data=[]
for i in range(len(data)):
    output_data.append(data[i].split('_'))
print('b)', "and c)")  
for i in range(len(output_data)):
    print(output_data[i])
# 6.4
data='A', 'B', 'C', 'AabX', 'BacX','', np.nan, 'CABA', 'dog', 'cat'
df=pd.Series(data)
print (df.str.replace('^.a|dog', 'XX-XX ', case=False))
# 6.5
dollar='12', '-$10', '$10,000'
df_dollar=pd.Series(dollar)
print (df_dollar.str.replace(r'$', ''))
# 6.6
pat=r'[a-z]+'
repl=lambda i: i.group(0)[::-1]
df=pd.Series(['india 1998', 'big country', np.nan]).str.replace(pat,repl)
print(df)
#6.7
df=pd.Series([1, 2, '1a', '2b', '2003c'])
print (df.str.isalnum())
#6.8
df=pd.Series(['1', '2', '1a', '2b', 'America', 'VietnAm','vietnam', '2003c'])
print (df.str.contains('A'))
#6.9
df=pd.Series(['a', 'a|b', np.nan, 'a|c'])
print (df.str.get_dummies(sep='|'))
#6.10
ltable={'key': ['One', 'Two'], 'ltable': [1, 2]}
rtable={'key': ['One', 'Two'], 'rtable': [4, 5]}
df=pd.DataFrame(data=ltable)
df1=pd.DataFrame(data=rtable)
df.add(df1,fill_value=0)
print (df)
# Out:
# a) Series elements in lower case 0      amit
# 1       bob
# 2      kate
# 3         a
# 4         b
# 5    np.nan
# 6       car
# 7       dog
# 8       cat
# dtype: object
# b) Series elements in UPPER case 0      AMIT
# 1       BOB
# 2      KATE
# 3         A
# 4         B
# 5    NP.NAN
# 6       CAR
# 7       DOG
# 8       CAT
# dtype: object
# c)
# Length of Amit = 4
# Length of Bob = 3
# Length of Kate = 4
# Length of A = 1
# Length of b = 1
# Length of np.nan = 6
# Length of Car = 3
# Length of dog = 3
# Length of cat = 3
# a)
# Atul
# John
# jack
# Sam
# b)
# Atul
# John
# jack
# Sam
# c)
#  Atul
# John
#  jack
# Sam
# a)
# b) and c)
# ['India', 'is', 'big']
# ['Population', 'is', 'huge']
# ['Has', 'diverse', 'culture']
# 0           A
# 1           B
# 2           C
# 3    XX-XX bX
# 4    XX-XX cX
# 5
# 6         NaN
# 7    XX-XX BA
# 8      XX-XX
# 9     XX-XX t
# dtype: object
# 0        12
# 1       -10
# 2    10,000
# dtype: object
# 0     aidni 1998
# 1    gib yrtnuoc
# ...
