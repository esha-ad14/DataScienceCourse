# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv ('FyntraCustomerData.csv')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
#Question 1
sns.jointplot(data=df,x='Time_on_Website',y='Yearly_Amount_Spent', color="lightblue")

#theres a weak correlation or no correlation as the data is scattered

# %%
#Question 2
sns.jointplot(data=df,x='Time_on_App',y='Yearly_Amount_Spent',color="lightblue")

#Theres a slightly more visible correlation in this graph in comparison to the other

# %%
#Question 3
sns.pairplot(df)

#Most correlated is between Length of Memebership and Yearly Time Spent

# %%
#Question 4
sns.lmplot(data=df, x='Length_of_Membership', y='Yearly_Amount_Spent')

#The data seems to fit the linear model fairly well, showing a semi-strong correlation

# %%
df.columns
x = df[['Avg_Session_Length', 'Time_on_App', 'Time_on_Website', 'Length_of_Membership']]
y = df['Yearly_Amount_Spent']

# %%
#Question 5
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=85)
X_train, X_test, y_train, y_test
# Out:
# (     Avg_Session_Length  Time_on_App  Time_on_Website  Length_of_Membership
#  302           32.975193    13.394452        37.806978              3.569047
#  109           33.356874    13.452129        38.503009              3.318822
#  320           32.495419    12.968326        38.296110              1.200484
#  88            31.956301    12.828893        36.951617              4.571213
#  464           32.533240    14.121784        38.406329              5.320094
#  ..                  ...          ...              ...                   ...
#  51            33.900224    10.956791        37.266878              2.952669
#  196           32.733224    11.818572        37.102031              1.503854
#  397           34.012619    12.914570        36.046204              3.488030
#  160           32.838100    12.364342        38.039109              3.309182
#  362           33.981006     9.316289        36.914952              2.868428
#
#  [250 rows x 4 columns],
# ...

# %%
#Question 6
from sklearn.linear_model import LinearRegression 
linm = LinearRegression()
linm.fit(X_train,y_train)
prediction = linm.predict(X_test)
plt.scatter(y_test,prediction, color="lightblue")
plt.xlabel('Y Test values')
plt.ylabel('Predicted values')

#some of the values match as they are both correlated
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
#Question 7
from sklearn import metrics
print ('Root Mean Squared Error:',np.sqrt(metrics.mean_squared_error(y_test,prediction)))
# Out:
# Root Mean Squared Error: 10.454363670707334
