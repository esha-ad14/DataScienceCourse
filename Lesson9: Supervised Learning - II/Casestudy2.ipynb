# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

# %%
#Question 1
df = pd.read_csv("run_or_walk.csv")
df
# Out:
#             date                time username  wrist  activity  \
# 0      2017-6-30  13:51:15:847724020   viktor      0         0
# 1      2017-6-30  13:51:16:246945023   viktor      0         0
# 2      2017-6-30  13:51:16:446233987   viktor      0         0
# 3      2017-6-30  13:51:16:646117985   viktor      0         0
# 4      2017-6-30  13:51:16:846738994   viktor      0         0
# ...          ...                 ...      ...    ...       ...
# 88583   2017-7-9   20:9:15:317911028   viktor      0         0
# 88584   2017-7-9   20:9:15:517889022   viktor      0         0
# 88585   2017-7-9   20:9:15:717828989   viktor      0         0
# 88586   2017-7-9   20:9:15:917932987   viktor      0         0
# 88587   2017-7-9   20:9:16:117410004   viktor      0         0
#
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# ...

# %%
#Question 2
x = df.iloc[:, 5:]
y = df["activity"]

# %%
#Question 3
train_x, test_x, train_y, test_y = train_test_split(
    x, y, random_state=10, test_size=0.25)

gaussian = GaussianNB()
gaussian.fit(train_x, train_y)

predictedVals = gaussian.predict(test_x)

print("Accuracy Score:",metrics.accuracy_score(predictedVals, test_y))

print("Classification Score")
print(metrics.classification_report(predictedVals, test_y))
# Out:
# Accuracy Score: 0.958685149230144
# Classification Score
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11725
#            1       0.93      0.99      0.96     10422
#
#     accuracy                           0.96     22147
#    macro avg       0.96      0.96      0.96     22147
# weighted avg       0.96      0.96      0.96     22147

# %%
#Quedtion 4
x1 = df.iloc[:, 5:8]
y1 = df["activity"]

train_x1, test_x1, train_y1, test_y1 = train_test_split(
    x1 , y1, random_state=10, test_size=0.25)

gaussian.fit(train_x1, train_y1)
predictedVals1 = gaussian.predict(test_x1)

print("Accuracy Score:",metrics.accuracy_score(predictedVals1, test_y1))

print("Classification Score")
print(metrics.classification_report(predictedVals1, test_y1))


# Gyro as Independent variables
x2 = df.iloc[:, 8:]
y2 = df["activity"]

train_x2, test_x2, train_y2, test_y2 = train_test_split(
    x2, y2, random_state=10, test_size=0.25)

gaussian.fit(train_x2, train_y2)
predictedVals2 = gaussian.predict(test_x2)

print("Accuracy Score:",metrics.accuracy_score(predictedVals2, test_y2))

print("Classification Score")
print(metrics.classification_report(predictedVals2, test_y2))
# Out:
# Accuracy Score: 0.9592721361809726
# Classification Score
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11768
#            1       0.93      0.99      0.96     10379
#
#     accuracy                           0.96     22147
#    macro avg       0.96      0.96      0.96     22147
# weighted avg       0.96      0.96      0.96     22147
#
# Accuracy Score: 0.6495687903553529
# Classification Score
#               precision    recall  f1-score   support
#
#            0       0.75      0.62      0.68     13181
#            1       0.55      0.69      0.61      8966
#
#     accuracy                           0.65     22147
#    macro avg       0.65      0.66      0.65     22147
# weighted avg       0.67      0.65      0.65     22147
